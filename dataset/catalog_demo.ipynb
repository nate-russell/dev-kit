# %% [markdown]
# # simple demo of DataCatalog
# - look at data sets
# - key word search for data sets
# - load them from disk if they exist if not fetch them from url
# - TODO: handle sdf,json,sqlite,tar,gzip

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from catalog import DataCatalog

# %%
dc = DataCatalog()
dc.catalog_as_df()
# Out:
#                                                  url               dir  \
# 0  https://www.probes-drugs.org/media/download/ta...  PROBES_AND_DRUGS
# 1  https://www.probes-drugs.org/media/download/co...  PROBES_AND_DRUGS
# 2  https://www.guidetopharmacology.org/DATA/inter...            IUPHAR
# 3  https://raw.githubusercontent.com/molecularinf...       Biogen_ADME
# 4  https://static-content.springer.com/esm/art%3A...           aliagas
# 5                                                  a                 a
#
#                       fname                                      notes  \
# 0            pd_targets.csv                                       todo
# 1          pd_compounds.csv                                       todo
# 2   iuphar_interactions.csv                                       todo
# 3  ADME_public_set_3521.csv                                       todo
# 4               aliagas.csv  https://pubmed.ncbi.nlm.nih.gov/35359246/
# ...

# %%
dc.keyword_search('probes')
# Out:
#                                                  url               dir  \
# 0  https://www.probes-drugs.org/media/download/ta...  PROBES_AND_DRUGS
# 1  https://www.probes-drugs.org/media/download/co...  PROBES_AND_DRUGS
#
#               fname notes                        dcid
# 0    pd_targets.csv  todo    probes_and_drugs_targets
# 1  pd_compounds.csv  todo  probes_and_drugs_compounds

# %%
dc.load('probes_and_drugs_targets')
# Out:
# f:\git_repos\dev-kit\dataset\catalog.py:141: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   if loader is None:
#             pdid      name                                        target_name  \
# 0       PD000001  BAZ2-ICR               Chromatin remodeling regulator CECR2
# 1       PD000001  BAZ2-ICR  Bromodomain adjacent to zinc finger domain pro...
# 2       PD000001  BAZ2-ICR  Bromodomain adjacent to zinc finger domain pro...
# 3       PD000002    I-BRD9               Chromatin remodeling regulator CECR2
# 4       PD000002    I-BRD9                               CREB-binding protein
# ...          ...       ...                                                ...
# 190795  PD205557  PD205557                                PRMT5/MEP50 complex
# 190796  PD205561  PD205561          Nucleosome-remodeling factor subunit BPTF
# 190797  PD205576  PD205576                Serine/threonine-protein kinase 17A
# ...

# %%
dc.load('probes_and_drugs_compounds',force_request=True)
# Out:
# https://www.probes-drugs.org/media/download/compounds/pd_export_02_2023_compounds_standardized.csv -> 'F:\\data\\PROBES_AND_DRUGS\\pd_compounds.csv'
#   0%|          | 0.00/45.0M [00:00<?, ?iB/s]
#             pdid      name                                             smiles  \
# 0       PD000001  BAZ2-ICR     Cn1cc(CCn2cnc(-c3cnn(C)c3)c2-c2ccc(C#N)cc2)cn1
# 1       PD000002    I-BRD9  CCn1cc(-c2cccc(C(F)(F)F)c2)c2sc(C(=N)NC3CCS(=O...
# 2       PD000003   UNC0638  COc1cc2c(NC3CCN(C(C)C)CC3)nc(C3CCCCC3)nc2cc1OC...
# 3       PD000004      LP99  Cc1cc(=O)n(C)c2cc(N3C(=O)CC[C@H](NS(=O)(=O)CC(...
# 4       PD000005   UNC1215  O=C(c1ccc(C(=O)N2CCC(N3CCCC3)CC2)c(Nc2ccccc2)c...
# ...          ...       ...                                                ...
# 112973  PD205587  PD205587    CN1CCN(C(=O)c2ccc3cc2OCCOCCNc2ccn4ncc-3c4n2)CC1
# 112974  PD205588  PD205588  COc1ccccc1CN(C)C(=O)Cn1c(CCC(=O)O)nc2c(Cl)cccc...
# ...
